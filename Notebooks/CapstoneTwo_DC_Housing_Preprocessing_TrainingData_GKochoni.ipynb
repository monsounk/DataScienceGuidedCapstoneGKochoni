# %% [markdown]
# ## Capstone Two - DC Housing Prices Predicting: Pre-processing & Training Data Development

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
df = pd.read_csv('DC_Properties.csv', low_memory=False)

# Basic cleaning
cols_to_drop = ['Unnamed: 0', 'SOURCE', 'CMPLX_NUM', 'GIS_LAST_MOD_DTTM',
                'SQUARE', 'X', 'Y', 'NATIONALGRID']
df.drop(columns=cols_to_drop, inplace=True, errors='ignore')
df = df[df['PRICE'] > 0]
df = df.drop_duplicates()

df.shape
# Out:
# (97832, 41)

# %%
# Select numeric and categorical features for encoding
df_model = df[['PRICE', 'ROOMS', 'BEDRM', 'BATHRM', 'LANDAREA', 'WARD', 'HEAT', 'STRUCT']].copy()
df_model = df_model.dropna(subset=['WARD', 'HEAT', 'STRUCT'])
df_model = df_model[df_model['WARD'].notnull()]
df_model.head()
# Out:
#        PRICE  ROOMS  BEDRM  BATHRM  LANDAREA    WARD           HEAT  \
# 0  1095000.0      8      4       4      1680  Ward 2      Warm Cool
# 2  2100000.0      9      5       3      1680  Ward 2  Hot Water Rad
# 3  1602000.0      8      5       3      1680  Ward 2  Hot Water Rad
# 5  1950000.0     10      5       3      2196  Ward 2  Hot Water Rad
# 7  1050000.0      8      4       3      1627  Ward 2  Hot Water Rad
#
#        STRUCT
# 0  Row Inside
# 2  Row Inside
# 3  Row Inside
# 5  Row Inside
# 7  Row Inside

# %%
# Dummy encoding for categorical features
df_encoded = pd.get_dummies(df_model, columns=['WARD', 'HEAT', 'STRUCT'], drop_first=True)
df_encoded.head()
# Out:
#        PRICE  ROOMS  BEDRM  BATHRM  LANDAREA  WARD_Ward 2  WARD_Ward 3  \
# 0  1095000.0      8      4       4      1680         True        False
# 2  2100000.0      9      5       3      1680         True        False
# 3  1602000.0      8      5       3      1680         True        False
# 5  1950000.0     10      5       3      2196         True        False
# 7  1050000.0      8      4       3      1627         True        False
#
#    WARD_Ward 4  WARD_Ward 5  WARD_Ward 6  ...  HEAT_Wall Furnace  \
# 0        False        False        False  ...              False
# 2        False        False        False  ...              False
# 3        False        False        False  ...              False
# 5        False        False        False  ...              False
# 7        False        False        False  ...              False
#
#    HEAT_Warm Cool  HEAT_Water Base Brd  STRUCT_Multi  STRUCT_Row End  \
# 0            True                False         False           False
# 2           False                False         False           False
# 3           False                False         False           False
# 5           False                False         False           False
# 7           False                False         False           False
#
#    STRUCT_Row Inside  STRUCT_Semi-Detached  STRUCT_Single  STRUCT_Town End  \
# 0               True                 False          False            False
# 2               True                 False          False            False
# 3               True                 False          False            False
# 5               True                 False          False            False
# 7               True                 False          False            False
#
#    STRUCT_Town Inside
# 0               False
# 2               False
# 3               False
# 5               False
# 7               False
#
# [5 rows x 32 columns]

# %%
# Separate predictors (X) and target (y)
X = df_encoded.drop(columns='PRICE')
y = df_encoded['PRICE']

# %%
# Standardize numeric features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X_scaled.head()
# Out:
#       ROOMS     BEDRM    BATHRM  LANDAREA  WARD_Ward 2  WARD_Ward 3  \
# 0  0.239203  0.516432  1.689195 -0.474329     4.005516    -0.397467
# 1  0.672668  1.411132  0.748974 -0.474329     4.005516    -0.397467
# 2  0.239203  1.411132  0.748974 -0.474329     4.005516    -0.397467
# 3  1.106132  1.411132  0.748974 -0.310403     4.005516    -0.397467
# 4  0.239203  0.516432  0.748974 -0.491166     4.005516    -0.397467
#
#    WARD_Ward 4  WARD_Ward 5  WARD_Ward 6  WARD_Ward 7  ...  HEAT_Wall Furnace  \
# 0    -0.468225    -0.445048     -0.44605     -0.39487  ...          -0.038344
# 1    -0.468225    -0.445048     -0.44605     -0.39487  ...          -0.038344
# 2    -0.468225    -0.445048     -0.44605     -0.39487  ...          -0.038344
# 3    -0.468225    -0.445048     -0.44605     -0.39487  ...          -0.038344
# 4    -0.468225    -0.445048     -0.44605     -0.39487  ...          -0.038344
#
#    HEAT_Warm Cool  HEAT_Water Base Brd  STRUCT_Multi  STRUCT_Row End  \
# 0        1.756709            -0.040326     -0.227199       -0.368009
# 1       -0.569246            -0.040326     -0.227199       -0.368009
# 2       -0.569246            -0.040326     -0.227199       -0.368009
# 3       -0.569246            -0.040326     -0.227199       -0.368009
# 4       -0.569246            -0.040326     -0.227199       -0.368009
#
#    STRUCT_Row Inside  STRUCT_Semi-Detached  STRUCT_Single  STRUCT_Town End  \
# 0           1.213126             -0.406453      -0.624579        -0.036492
# 1           1.213126             -0.406453      -0.624579        -0.036492
# 2           1.213126             -0.406453      -0.624579        -0.036492
# 3           1.213126             -0.406453      -0.624579        -0.036492
# 4           1.213126             -0.406453      -0.624579        -0.036492
#
#    STRUCT_Town Inside
# 0           -0.056617
# 1           -0.056617
# 2           -0.056617
# 3           -0.056617
# 4           -0.056617
#
# [5 rows x 31 columns]

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((46319, 31), (11580, 31), (46319,), (11580,))

# %% [markdown]
# ## Summary of Pre-processing Steps
#
# - Selected both numerical and categorical variables relevant to house pricing.
# - Created dummy variables for `WARD`, `HEAT`, and `STRUCT` to convert categorical features.
# - Applied standard scaling to the predictors to normalize the feature ranges.
# - Split the dataset into training and testing subsets using an 80/20 ratio.
